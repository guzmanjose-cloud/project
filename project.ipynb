# %%
df
# Out:
#                                                title  \
# 0                                         Technology
# 1                                         Technology
# 2  Trending Technology News and Insights by Tech ...
# 3        Mighty Gadget: UK Technology News & Reviews
# 4                            Construction Technology
# 5  Home - Lutheran Alliance for Faith, Science an...
# 6  CSET - Center for Security and Emerging Techno...
# 7                  Homepage | gHacks Technology News
# 8             Investor Relations | Micron Technology
# 9  InApps Technology | Leading the Mobile App Dev...
#
#                                                 name  \
# 0                                        HousingWire
# 1                                                WSJ
# 2    Tech Geeked | Technology and Entertainment News
# 3  Mighty Gadget Blog: UK Technology News and Rev...
# 4                            Construction Technology
# 5  Lutheran Alliance for Faith, Science and Techn...
# ...

# %%
df.columns
# Out:
# Index(['title', 'name', 'url', 'language', 'category', 'description', 'logo',
#        'favicon', 'links'],
#       dtype='object')
